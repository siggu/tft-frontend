# %%
import numpy as np
import pandas as pd
import requests
import time

# api_key 설정
api_key = "RGAPI-b19ae88a-58de-455a-8b57-bd3160ee8bd8"

# request_header 설정
request_header = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36",
    "Accept-Language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "Accept-Charset": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://developer.riotgames.com",
    "X-Riot-Token": api_key,
}

# base_url 설정
base_url = "https://kr.api.riotgames.com/tft/"

# %%
# 챌린저
challenger_url = base_url + "league/v1/challenger"

challenger = requests.get(challenger_url, headers=request_header).json()

# 그랜드마스터
grandmaster_url = base_url + "league/v1/grandmaster"

grandmaster = requests.get(grandmaster_url, headers=request_header).json()

# 마스터
master_url = base_url + "league/v1/master"

master = requests.get(master_url, headers=request_header).json()

challenger_df = pd.DataFrame(challenger["entries"])
grandmaster_df = pd.DataFrame(grandmaster['entries'])
master_df = pd.DataFrame(master['entries'])

challenger_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 다이아 이하 랭크 유저
dia1_page1_url = base_url + 'league/v1/entries/DIAMOND/IV?page=1'

dia1_page1 = requests.get(dia1_page1_url, headers = request_header).json()

dia1_page1_df = pd.DataFrame(dia1_page1)

dia1_page1_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 유저 PUUID 추출
id_url = base_url + "summoner/v1/summoners/by-name/게임어려웡"

my_id = requests.get(id_url, headers = request_header).json()

# print(my_id)
my_id
# Out:
# {'id': 'cLxH4wzhqGWrh1dYJfZ84m9lPFAsbsvxwY6SouUZu7fJC-8',
#  'accountId': '4CLx7Y2koDmeotwkeAbRqnjxz08N_M9gbk39r49xZ0c1lwFzEN8DLT7P',
#  'puuid': 'tcTeDJyWr7TjVOtJsFdziIowZufAx6CkRxZsOl_xqekcf0hqqTtExHnVqgqVnZj_-adG7AOmSZc58g',
#  'name': '게임어려웡',
#  'profileIconId': 4491,
#  'revisionDate': 1710981637022,
#  'summonerLevel': 80}

# %%
# 유저가 플레이한 game id 추출
puu_id = my_id['puuid']
game_url = "https://Asia.api.riotgames.com/tft/" + f'match/v1/matches/by-puuid/{puu_id}/ids?count=20'

game_id = requests.get(game_url, headers = request_header).json()

game_id
# Out:
# ['KR_6995242432',
#  'KR_6994599451',
#  'KR_6994560936',
#  'KR_6994518215',
#  'KR_6994477685',
#  'KR_6994376454',
#  'KR_6994334995',
#  'KR_6994309774',
#  'KR_6994278898',
#  'KR_6994262615',
#  'KR_6994182933',
#  'KR_6994186053',
#  'KR_6994171501',
#  'KR_6994174019',
#  'KR_6988357714',
#  'KR_6988336212',
#  'KR_6988306436',
#  'KR_6988132881',
#  'KR_6988066618',
#  'KR_6988047423']

# %%
# Game id로 game 데이터 추출하기

first_game_id = game_id[0]

game_result_url = "https://Asia.api.riotgames.com/tft/" + f"match/v1/matches/{first_game_id}"

game_result = requests.get(game_result_url, headers=request_header).json()

game_result_df = pd.DataFrame(game_result['info'])

game_result_df
# Out:
#   endOfGameResult   gameCreation      gameId  game_datetime  game_length  \
# 0    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
# 1    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
# 2    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
# 3    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
# 4    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
# 5    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
# 6    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
# 7    GameComplete  1710979363000  6995242432  1710981634342  2246.101562
#
#                                         game_version  mapId  \
# 0  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
# 1  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
# 2  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
# 3  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
# 4  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
# 5  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
# 6  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
# 7  Version 14.6.568.8373 (Mar 18 2024/18:02:49) [...     22
#
#                                         participants  queueId  queue_id  \
# 0  {'augments': ['TFT11_Augment_InkshadowCrest', ...     1090      1090
# 1  {'augments': ['TFT11_Augment_WanderingTrainerG...     1090      1090
# 2  {'augments': ['TFT6_Augment_PortableForge', 'T...     1090      1090
# 3  {'augments': ['TFT9_Augment_Martyr', 'TFT11_Au...     1090      1090
# 4  {'augments': ['TFT9_Augment_YouHaveMyBow', 'TF...     1090      1090
# 5  {'augments': ['TFT11_Augment_WanderingTrainerG...     1090      1090
# 6  {'augments': ['TFT9_Augment_KnowYourEnemy', 'T...     1090      1090
# 7  {'augments': ['TFT11_Augment_Behemoth', 'TFT9_...     1090      1090
#
#   tft_game_type tft_set_core_name  tft_set_number
# 0      standard          TFTSet11              11
# 1      standard          TFTSet11              11
# 2      standard          TFTSet11              11
# 3      standard          TFTSet11              11
# 4      standard          TFTSet11              11
# 5      standard          TFTSet11              11
# 6      standard          TFTSet11              11
# 7      standard          TFTSet11              11

# %%
# 게임을 같이 한 유저
participants = pd.DataFrame(game_result['info']['participants'])

participants
# Out:
#                                             augments  \
# 0  [TFT11_Augment_InkshadowCrest, TFT9_Augment_He...
# 1  [TFT11_Augment_WanderingTrainerGold, TFT11_Aug...
# 2  [TFT6_Augment_PortableForge, TFT11_Augment_Epo...
# 3  [TFT9_Augment_Martyr, TFT11_Augment_RainingGol...
# 4  [TFT9_Augment_YouHaveMyBow, TFT9_Augment_BigGr...
# 5  [TFT11_Augment_WanderingTrainerGold, TFT9_Augm...
# 6  [TFT9_Augment_KnowYourEnemy, TFT9_Augment_Heal...
# 7  [TFT11_Augment_Behemoth, TFT9_Augment_Formatio...
#
#                                            companion  gold_left  last_round  \
# 0  {'content_ID': '8c27f67c-90b3-4355-9e90-6e9232...          3          31
# 1  {'content_ID': '2fc3a4c0-7322-4ef5-b434-0cea1d...          0          35
# 2  {'content_ID': 'e0dabd7f-6f9c-4b89-a73d-587c34...          1          33
# 3  {'content_ID': 'ee3fda5c-1956-44fe-a4a4-377483...          6          27
# 4  {'content_ID': '87f906e8-27c1-48f9-86e2-a7d74a...          4          30
# 5  {'content_ID': '6c2562ad-42ed-4578-9a12-63d27b...          3          28
# 6  {'content_ID': 'c937670f-1586-4a2b-a046-e4bb2c...          1          37
# 7  {'content_ID': '195fbc7f-66b0-4ae8-89e6-ff106a...          1          37
#
#    level                                           missions  placement  \
# 0      8  {'Assists': 0, 'DamageDealt': 1, 'DamageDealtT...          5
# 1      8  {'Assists': 0, 'DamageDealt': 0, 'DamageDealtT...          3
# 2      9  {'Assists': 0, 'DamageDealt': 0, 'DamageDealtT...          4
# 3      9  {'Assists': 0, 'DamageDealt': 0, 'DamageDealtT...          8
# 4      9  {'Assists': 0, 'DamageDealt': 0, 'DamageDealtT...          6
# 5      9  {'Assists': 0, 'DamageDealt': 1, 'DamageDealtT...          7
# 6      8  {'Assists': 0, 'DamageDealt': 0, 'DamageDealtT...          1
# 7      8  {'Assists': 0, 'DamageDealt': 1, 'DamageDealtT...          2
#
#    players_eliminated                                              puuid  \
# 0                   0  RR2dlWpnYxB3aGXVlN8FYYm2LaK-8WEu50c8QZGYRkraJc...
# 1                   2  aBwPRi5W6dh67cZxAa1jPgct9v6hVhb8dE7I88YAX-ffbu...
# 2                   1  jTQHr6k5tcI3-rRO46XMi75Dwi1FhIpjb_6HjuyojimPOe...
# 3                   0  jiqoGjgG7SrLt_IDdXPhn5h8D04iopuCc2vDEcMXVRD0ik...
# 4                   0  sn_0a8EYb0YJPDTo0rZ3UCkpRnv8FfNwU-qc646t7QJ_Q-...
# 5                   0  tcTeDJyWr7TjVOtJsFdziIowZufAx6CkRxZsOl_xqekcf0...
# 6                   3  OF0eo3Gaxi6z0y9QHMX41zCvuCAuIanBe1njmZyhhVgns0...
# 7                   1  A5iu91TIFDnRiWX9eLuusfSxFlc0F0vDeeTadhQDXs2vxy...
#
#    time_eliminated  total_damage_to_players  \
# 0      1919.057861                       95
# 1      2157.964355                      123
# 2      2028.831787                      102
# 3      1667.879272                       55
# 4      1844.982910                       83
# 5      1740.834106                       64
# 6      2237.969238                      156
# 7      2237.969238                      145
#
#                                               traits  \
# 0  [{'name': 'TFT11_Behemoth', 'num_units': 2, 's...
# 1  [{'name': 'TFT11_Altruist', 'num_units': 4, 's...
# 2  [{'name': 'TFT11_Behemoth', 'num_units': 1, 's...
# 3  [{'name': 'TFT11_Altruist', 'num_units': 1, 's...
# 4  [{'name': 'TFT11_Artist', 'num_units': 1, 'sty...
# 5  [{'name': 'TFT11_Altruist', 'num_units': 4, 's...
# 6  [{'name': 'TFT11_Arcanist', 'num_units': 1, 's...
# 7  [{'name': 'TFT11_Arcanist', 'num_units': 1, 's...
#
#                                                units
# 0  [{'character_id': 'TFT11_Jax', 'itemNames': ['...
# 1  [{'character_id': 'TFT11_Sivir', 'itemNames': ...
# 2  [{'character_id': 'TFT11_Aatrox', 'itemNames':...
# 3  [{'character_id': 'TFT11_Lux', 'itemNames': []...
# 4  [{'character_id': 'TFT11_Yorick', 'itemNames':...
# 5  [{'character_id': 'TFT11_Riven', 'itemNames': ...
# 6  [{'character_id': 'TFT11_Malphite', 'itemNames...
# 7  [{'character_id': 'TFT11_ChoGath', 'itemNames'...

# %%
# augments/companion/gold_left/last_round/level/missions/placement/players_eliminated/puuid/time_eliminated/total_damage_to_players/traits/units

# traits(origin, job) 확인
first_user_trait = pd.DataFrame(participants.loc[0, 'traits'])
first_user_trait

# unit(champion) 확인
first_user_unit = pd.DataFrame(participants.loc[0, 'units'])

print(first_user_trait)
first_user_unit
# Out:
#                   name  num_units  style  tier_current  tier_total
# 0       TFT11_Behemoth          2      1             1           3
# 1        TFT11_Bruiser          1      0             0           4
# 2     TFT11_Dragonlord          1      0             0           4
# 3          TFT11_Dryad          1      0             0           3
# 4        TFT11_Duelist          1      0             0           4
# 5        TFT11_Exalted          1      0             0           2
# 6        TFT11_Ghostly          1      0             0           4
# 7      TFT11_InkShadow          7      3             3           3
# 8         TFT11_Lovers          1      5             1           1
# 9         TFT11_Sniper          1      0             0           3
# 10  TFT11_SpiritWalker          1      5             1           1
# 11     TFT11_Trickshot          2      1             1           2
# 12        TFT11_Warden          1      0             0           3
#      character_id                                          itemNames name  \
# 0       TFT11_Jax  [TFT_Item_ThiefsGloves, TFT_Item_RunaansHurric...
# 1    TFT11_Aatrox  [TFT_Item_ThiefsGloves, TFT_Item_BlueBuff, TFT...
# 2     TFT11_Senna          [TFT_Item_Shroud, TFT_Item_PowerGauntlet]
# 3  TFT11_Volibear  [TFT_Item_DragonsClaw, TFT_Item_RedBuff, TFT11...
# 4     TFT11_Kaisa  [TFT_Item_GuinsoosRageblade, TFT4_Item_OrnnThe...
# 5      TFT11_Ornn  [TFT_Item_AegisOfTheLegion, TFT11_Item_InkShad...
# 6     TFT11_Xayah  [TFT_Item_GuinsoosRageblade, TFT_Item_MadredsB...
# 7      TFT11_Udyr  [TFT11_Item_InkshadowHorse, TFT_Item_HextechGu...
#
#    rarity  tier
# 0       0     2
# 1       1     2
# 2       1     2
# 3       2     2
# 4       4     2
# 5       4     2
# 6       6     1
# 7       6     1
